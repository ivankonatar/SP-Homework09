# %%
from PIL import Image
img = Image.open('1e4f0ed345dbc759f81fc9ebb4a36823.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x348 at 0x2AE66E12198>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

img = mpimg.imread('1e4f0ed345dbc759f81fc9ebb4a36823.jpg')     
gray = rgb2gray(img)    
plt.imshow(gray, cmap = plt.get_cmap('gray'))
plt.show()
